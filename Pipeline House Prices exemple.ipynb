# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('train.csv')
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
# target
y = df['SalePrice']
# features
X = df[['LotArea','Street','MiscFeature']]

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn import set_config
set_config(display='diagram')

# %%
pipe_category = Pipeline([
    ('replace_NaN2',SimpleImputer(strategy='most_frequent')),
    ('pipeline_cat',OneHotEncoder())])
pipe_category
# Out:
# Pipeline(steps=[('replace_NaN2', SimpleImputer(strategy='most_frequent')),
#                 ('pipeline_cat', OneHotEncoder())])

# %%
pipe_numeric = Pipeline([('replace_NaN',SimpleImputer()),('minmaxscaler',MinMaxScaler())])
pipe_numeric
# Out:
# Pipeline(steps=[('replace_NaN', SimpleImputer()),
#                 ('minmaxscaler', MinMaxScaler())])

# %%
from sklearn.compose import ColumnTransformer

# %%
pipe_transf = ColumnTransformer([('transf_cat', pipe_category, df.dtypes=='object'),
                                 ('transf_num', pipe_numeric, df.dtypes=='int64'),
                                 ('transf_float', pipe_numeric, df.dtypes=='float64')])
pipe_transf
# Out:
# ColumnTransformer(transformers=[('transf_cat',
#                                  Pipeline(steps=[('replace_NaN2',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('pipeline_cat',
#                                                   OneHotEncoder())]),
#                                  Id               False
# MSSubClass       False
# MSZoning          True
# LotFrontage      False
# LotArea          False
#                  ...
# MoSold           False
# YrSold           False
# SaleType          True
# SaleCondition     True
# SalePrice        False
# Length: 81, dtype: bool),
#                                 ('transf_num',
#                                  Pipeline(steps=[('replace_NaN'...
# LotArea           True
#                  ...
# MoSold            True
# YrSold            True
# SaleType         False
# SaleCondition    False
# SalePrice         True
# ...

# %%
# pipe_transf.fit_transform(X)

# %%
from sklearn.linear_model import LinearRegression
from sklearn import linear_model

# %%
pipe_model = Pipeline([('pipe_transf',pipe_transf),
                       ('modele',LinearRegression())])
pipe_model
# Out:
# Pipeline(steps=[('pipe_transf',
#                  ColumnTransformer(transformers=[('transf_cat',
#                                                   Pipeline(steps=[('replace_NaN2',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('pipeline_cat',
#                                                                    OneHotEncoder())]),
#                                                   Id               False
# MSSubClass       False
# MSZoning          True
# LotFrontage      False
# LotArea          False
#                  ...
# MoSold           False
# YrSold           False
# SaleType          True
# SaleCondition     True
# SalePrice        False
# Length: 81, dtype: bool),
#                                                  ('transf_num'...
# SaleType         False
# SaleCondition    False
# SalePrice         True
# Length: 81, dtype: bool),
# ...

# %%
# pipe_model.fit(X,y)

# %%
pipe_model.score(X,y)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-13-a9aae52f5a38> in <module>
# ----> 1 pipe_model.score(X,y)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\metaestimators.py in <lambda>(*args, **kwargs)
#     117
#     118         # lambda, but not partial, allows help() to work with update_wrapper
# --> 119         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     120         # update the docstring of the returned function
#     121         update_wrapper(out, self.fn)
#
# ~\anaconda3\lib\site-packages\sklearn\pipeline.py in score(self, X, y, sample_weight)
#     605         Xt = X
#     606         for _, name, transform in self._iter(with_final=False):
# --> 607             Xt = transform.transform(Xt)
#     608         score_params = {}
#     609         if sample_weight is not None:
#
# ...
